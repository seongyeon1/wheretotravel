# %% [markdown]
# 구분	세부내용
# 데이터명	이동통신데이터
# 데이터 제공처	㈜케이티
# 제공 목적	지역방문자 이동행태 분석
# 데이터 기간	2018년~
# 데이터 단위	일단위
# 적재주기	일단위
# 작성체계	㈜케이티 → 한국관광공사
# 분석내용	지자체별 방문자수 및 증감률
# 주요용어해설	한국관광공사 '관광빅데이터 분석 가이드라인 수립연구(2020년)'에 의거 방문자 이동행태 분석
# 방문자 : 일상생활권(거주, 통근, 통학 등)을 벗어나 관광 등의 목적으로 한 장소(분석 대상 공간)에 일정시간 이상 체류한 사람으로 정의함. 해당 데이터는 이동통신데이터를 원천으로 하고 있으므로 방문 목적은 정확히 구분 불가능
# 1) 행정구역 방문자
# 광역지자체 방문자 : 해당 광역지자체 기준, 거주민 방문자(현지인), 외지인 방문자, 외국인 방문자로 구분
# 기초지자체 방문자 : 해당 기초지자체 기준, 거주민 방문자(현지인), 외지인 방문자, 외국인 방문자로 구분
# 행정동 방문자 : 해당 행정동 기준, 거주민 방문자(현지인), 외지인 방문자, 외국인 방문자로 구분
# 2) 특정지점 방문자
# 관광지점 방문자 : 해당 관광지가 속한 시군구 기준, 현지인 방문자, 외지인 방문자, 외국인 방문자로 구분
# 축제지점 방문자 : 해당 관광지가 속한 시군구 기준, 현지인 방문자, 외지인 방문자, 외국인 방문자로 구분
# * (KT 분석기준) "일정시간 이상"이라 함은 해당 지자체 내, 특정 기지국에 30분 이상 체류 기준임
# 현지인 : 해당 지자체(분석 대상 공간)의 상주자(거주자, 근무자, 통학자 등으로 추정되는 사람)
# 현지인 방문자 : 행정동 기준, 해당 광역/기초지자체에 속한 행정동 상주민 중 본인이 상주하고 있는 행정동 이외 행정동 방문자. 예를들어, 서울특별시 종로구 창신동 거주민이 익선동 내에서 30분이상 체류한 경우 현지인 방문자로 구분됨
# * (KT 분석기준) 통근/통학지 : 전월 기준, 해당 지역에 07~18시 사이에 4시간 이상&10일 이상 체류한 기초지자체
# * (KT 분석기준) 거주지 : 전월 기준, 해당 지역에 19~06 사이에 4시간 이상&10일 이상 체류한 기초지자체
# 외지인 : 기초지자체 기준, 해당 지자체(분석 대상 공간)에 상주(거주, 통학, 통근 등)하고 있지 않은 사람
# * (KT 분석기준) 특정지점 기준, 해당 기간 이전 1개월 동안 월 3회 이하 방문자
# 외국인 : 본인 국가에서 구매한 USIM을 제거 하지 않은 외국인이 한국에서 통신사(KT)와 신호를 주고받는 서비스를 사용하는 사람 (통신사간의 협약에 의해 넘어오는 통신사 기준 시그널 데이터로 국가 추정)
# * 외국인은 한국 단기체류자에 한함(과거 60일 기준, 15일 이하 체류자)
# 방문자 거주지 : 해당기간 이전 1개월 동안 밤 상주 기지국 기준의 기초지자체
# 방문자 유출지 : 방문자의 24시간 이후 유출지(시군구 기준)
# 기초지자체 : 250개 기초지자체 기준(기초지자체 하부 행정구 32개 포함)
# * 250개 기초지자체 세부 구분 기준은 해석유의사항 참조

# %% [markdown]
# 해석 유의사항	세부내용
# 실제 방문자수가 아닌 추정된 값임.
# 그러므로 절대수치가 아닌 증감율등의 추세분석용으로 활용하는 것이 바람직함	특정 이동통신사 가입자 데이터(KT)를 활용하여 전체 방문객수를 추정하였음
# 방문자수 추정 과정에서 실제보다 과대 또는 과소 추정되었을 가능성이 존재하기 때문에
# 방문자수의 절대수치가 아니라 증감율 등 추세분석용으로 활용하는 것이 바람직함
# 특히 아래와 같은 이유로 이동통신 데이터는 방문자수가 과소, 과대 추정되었을 가능성이 있음
# 이동통신 데이터의 시간적, 공간적 정의에 따라 방문자수 등에 차이가 발생할 수 있음
# 데이터 추출기간의 이동통신방식(1X, 2G, 3G, 4G, 5G 등) 및 기지국 전파영역의 변화에 따라 알고리즘 및 데이터 추출과정이 변경될 수 있음
# 고속도로, 도로, 철도 등 해당지역의 통과고객이 집계될 수 있음
# 핸드폰 미소지자 등의 누락이 있을 수 있음
# 배후지역의 도시화 정도에 따라 과소 또는 과대 추정될 수 있음
# 외국인의 경우 로밍서비스를 이용한 외국인만 집계가능함
# 정확한 방문목적을 알 수 없음	한국관광 데이터 랩에서 활용하고 있는 "방문자"는 일상생활권(거주, 통근, 통학 등)을 벗어나 관광 등의 목적으로 한 장소(분석대상 공간)에 일정시간 이상 머무른 사람으로 정의하였음
# 그러나 이동통신데이터의 특성상 정확한 방문목적은 알 수 없기 때문에 분석대상 공간에 비일상적으로 방문하였음을 추정하기 위해 다음과 같은 분석로직을 적용함.
# 즉 상주지(통학, 통근, 거주지 등)를 추정하여 상주인구 제외, 통과인구 제외, 전월기준 방문횟수가 많은 방문자 제외 등을 분석로직에 적용하여 최종 방문자수를 추정함
# 방문자수는 일 순방문자수
# (unique visitor) 기준임	방문자수는 일 순방문자 수(unique visitor) 기준임
# 예를 들어 A씨 4인 가족이 전주시 완산구를 1월 1일~1월 3일(2박 3일) 동안 방문하였을 경우,
# 1월 1일 4명, 1월 2일 4명, 1월 3일 4명 방문하여 총 12명이 방문한 것으로 산출됨.
# 250개 기초지자체는 다음과 같은
# 기준에 의해서 추출됨	250개 기초지자체(e) 기준 적용 : [ e=(a+b+d)-c ] [ 250=(226+3+32)-11 ]
# (a) 행안부 기준, 226개 기초지자체
# (b) 226개 기초지자체에 제주특별자치도의 제주시, 서귀포시와 세종특별자치시의 세종시 등 3개 행정시
# (c) 고양, 성남, 수원, 안산, 안양, 용인, 전주, 창원, 천안, 청주, 포항 11개 기초지자체
# (d) 고양, 성남, 수원, 안산, 안양, 용인, 전주, 창원, 천안, 청주, 포항 11개 기초지자체의 하위 행정구 32개
# 임의로 데이터 합산 분석 불가	임의로 방문객수를 합하여 결과 분석 불가
# 위의 11개 기초지자체 하위 행정구 32개에 대하여 임의로 데이터 합산하여 기초지자체 방문객수 집계 불가
# (전주시 방문자수 ≠ 전주시 완산구 방문자수 + 전주시 덕진구 방문자수)
# 기초지자체별 방문자수를 합하여 광역지자체별 방문자수 집계 불가
# '기타 국가' 정의	22개 주요국가를 제외한 국가의 합계
# (22개 주요국가) 대만 / 독일 / 러시아 / 말레이시아 / 몽골 / 미국 / 베트남 / 싱가포르 / 영국 / 인도 / 인도네시아 / 일본 / 중국 / 프랑스 / 필리핀 / 호주 / 홍콩 / 카자흐스탄 / 캐나다 / 터키 / 태국 / UAE

# %% [markdown]
# https://datalab.visitkorea.or.kr/datalab/portal/bda/getLocgoAna.do

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

from matplotlib import font_manager, rc
font_path = "C:\Windows\Fonts\gulim.ttc"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
# BC 카드 데이터
cost = pd.read_csv('./data1/광역지자체 관광지출액.csv')
cost.reset_index(drop=False, inplace=True)

cost.columns = cost.iloc[0]
cost.columns = ['지역', '구분', '201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910',
       '201911', '201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010',
       '202011', '202012', '202101', '202102', '202103', '202104', '202105']

cost = cost.drop(0)
cost = cost.set_index(['지역','구분']) 

cost.columns = pd.to_datetime(cost.columns, format='%Y%m')
cost = cost.T

for (i, j) in cost.columns:
    cost.loc[:,(i,j)] = cost.loc[:,(i,j)].str.replace(',','').astype('int64')

# %%
cost.columns
# Out:
# MultiIndex([(     '전국',        '총소비'),
#             (     '전국',        '숙박업'),
#             (     '전국',        '여행업'),
#             (     '전국',       '대중교통'),
#             (     '전국',        '렌터카'),
#             (     '전국',        '항공사'),
#             (     '전국',        '카지노'),
#             (     '전국',      '레저스포츠'),
#             (     '전국',        '면세점'),
#             (     '전국',      '문화서비스'),
#             ...
#             ('제주특별자치도',        '여행업'),
#             ('제주특별자치도',       '대중교통'),
#             ('제주특별자치도',        '렌터카'),
#             ('제주특별자치도',        '항공사'),
#             ('제주특별자치도',        '카지노'),
#             ('제주특별자치도',      '레저스포츠'),
#             ('제주특별자치도',        '면세점'),
#             ('제주특별자치도',      '문화서비스'),
#             ('제주특별자치도', '쇼핑(면세점 제외)'),
#             ('제주특별자치도',        '식음료')],
#            names=['지역', '구분'], length=183)

# %%
# 이동통신자료
cnt = pd.read_csv('./data1/광역지자체 방문자수.csv')
cnt.reset_index(drop=False, inplace=True)

cnt.columns = cnt.iloc[0]

cnt.columns = ['지역', '구분', '201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910',
       '201911', '201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010',
       '202011', '202012', '202101', '202102', '202103', '202104', '202105','202106']

cnt = cnt.drop(0)
cnt = cnt.set_index(['지역','구분']) 

cnt.columns = pd.to_datetime(cnt.columns, format='%Y%m')
cnt = cnt.T

for (i, j) in cnt.columns:
    cnt.loc[:,(i,j)] = cnt.loc[:,(i,j)].str.replace(',','').astype('int')

# %%
cnt
# Out:
# 지역                 전국                                                \
# 구분             현지인(a)     외지인(b)   외국인(c) 외부방문자(b+c) 전년외부방문자(b'+c')
# 2019-01-01  681997610  216038820  4755719  220794539      209401899
# 2019-02-01  592580236  220373580  4793419  225166999      208252992
# 2019-03-01  701908000  271202676  5274725  276477401      248720478
# 2019-04-01  640311882  207230460  6145658  213376119      211823035
# 2019-05-01  677198134  239603808  5538558  245142367      239308793
# 2019-06-01  649221612  229760916  5148186  234909102      219622375
# 2019-07-01  655834067  262371242  5857943  268229185      244939880
# 2019-08-01  653247220  293042802  6371252  299414055      251357076
# 2019-09-01  644024672  269626354  6298050  275924403      269774787
# 2019-10-01  671461402  252879781  7284223  260164004      239477486
# 2019-11-01  698550632  252847500  6940696  259788197      218325691
# 2019-12-01  718104180  233213418  7212219  240425636      226473337
# ...

# %%
# 네비게이션
nav = pd.read_csv('./data1/광역지자체 목적지 검색건수.csv')
nav.reset_index(drop=False, inplace=True)

nav.columns = nav.iloc[0]
nav.columns = ['지역', '구분', '201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910',
       '201911', '201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010',
       '202011', '202012', '202101', '202102', '202103', '202104', '202105', '202106']

nav = nav.drop(0)
nav = nav.set_index(['지역','구분']) 

nav.columns = pd.to_datetime(nav.columns, format='%Y%m')

nav = nav.T

for (i, j) in nav.columns:
    nav.loc[:,(i,j)] = nav.loc[:,(i,j)].str.replace(',','').astype('int')

# %%
nav
# Out:
# 지역                전국                                                         \
# 구분                전체    자연관광지   역사관광지   휴양관광지   공연/행사    문화시설 레포츠(육상/해상/항공)
# 2019-01-01  11369573   606712  232898  239952  354758  310699        345234
# 2019-02-01  11211203   649348  269108  254529  405922  314679        360249
# 2019-03-01  13144346   855949  299180  252366  354697  371152        576106
# 2019-04-01  13180204  1028688  324300  265223  354443  350365        677824
# 2019-05-01  15331841  1288188  410472  316467  424750  405291        804474
# 2019-06-01  15694410  1273800  341343  320763  498953  413664        823313
# 2019-07-01  15856655  1159988  298582  300837  448849  400374        758604
# 2019-08-01  19776676  1731531  418403  427366  496837  565164        869556
# 2019-09-01  14479165  1052006  315223  249065  350168  363019        716154
# 2019-10-01  17577844  1440271  450709  338721  394401  474866        927401
# ...

# %%
# 네비 / 이동통신 = 차량으로 이동해온 사람비중정도
((nav['서울특별시']['문화시설'])/(cnt['서울특별시']['현지인(a)']+cnt['서울특별시']['외부방문자(b+c)'])).plot(marker='o')
# Out:
# <AxesSubplot:>

# %%
((nav['서울특별시']['자연관광지'])/(cnt['서울특별시']['현지인(a)']+cnt['서울특별시']['외부방문자(b+c)'])).plot(marker='o')
((nav['경기도']['자연관광지'])/(cnt['경기도']['현지인(a)']+cnt['경기도']['외부방문자(b+c)'])).plot(marker='o')
((nav['강원도']['자연관광지'])/(cnt['강원도']['현지인(a)']+cnt['강원도']['외부방문자(b+c)'])).plot(marker='o')
# Out:
# <AxesSubplot:>

# %%
((nav['서울특별시']['자연관광지'])/(cnt['서울특별시']['현지인(a)'])).plot(marker='o')
# Out:
# <AxesSubplot:>

# %%
# 네비 / 이동통신 = 차량으로 이동해온 사람비중정도
# Out:
# <AxesSubplot:>

# %% [markdown]
# 지자체 지출액(BC), 검색건수(네비게이션), 이동통신(방문자수)

# %%
cnt['서울특별시']['외지인(b)']
# Out:
# 2019-01-01    49167240
# 2019-02-01    43909075
# 2019-03-01    60777356
# 2019-04-01    43323472
# 2019-05-01    51738645
# 2019-06-01    51421888
# 2019-07-01    58264846
# 2019-08-01    62843266
# 2019-09-01    57545747
# 2019-10-01    56278649
# 2019-11-01    60061148
# 2019-12-01    53230254
# 2020-01-01    49980364
# 2020-02-01    39887253
# 2020-03-01    35875693
# 2020-04-01    37482358
# 2020-05-01    42751230
# 2020-06-01    39775204
# 2020-07-01    44764482
# 2020-08-01    38545374
# 2020-09-01    36548505
# 2020-10-01    43963000
# 2020-11-01    40713340
# 2020-12-01    33025762
# 2021-01-01    35471954
# 2021-02-01    37521838
# 2021-03-01    46699880
# 2021-04-01    38039834
# 2021-05-01    41247518
# 2021-06-01    40567944
# Name: 외지인(b), dtype: int32

# %%
# 차량(자가용)을 이용한 관광이 증가하고 있다
(nav['전국']['자연관광지']/ cnt['전국']['외부방문자(b+c)']).plot()
# Out:
# <AxesSubplot:>

# %%
# 전체 관광에서 자동차를 이용한 관광의 비중이 눈에띄게 증가
(nav['전국']['전체']/ cnt['전국']['외부방문자(b+c)']).plot()
# Out:
# <AxesSubplot:>

# %%
# 자동차 등록대수가 적은 지역
# 문화시설이 충분히 있는 지역

# 대중교통이 안좋은 곳 -> 자동차 등록대수
# 인구 당

# %%
# 네비게이션
nav = pd.read_csv('./data1/주요관광지점 입장객_인천.csv')

# %%
nav
# Out:
#         시도   군구      관광지 내/외국인 총계(2019.01 ~ 2021.03)    2019년 Unnamed: 6  \
# 0      NaN  NaN      NaN   NaN                   NaN      인원계  2019년 01월
# 1    인천광역시   중구      무의도   내국인                58,787   58,787     12,589
# 2    인천광역시   중구      무의도    합계                58,787   58,787     12,589
# 3    인천광역시   중구  섬이야기박물관   내국인               101,945      NaN        NaN
# 4    인천광역시   중구  섬이야기박물관    합계               101,945      NaN        NaN
# ..     ...  ...      ...   ...                   ...      ...        ...
# 132  인천광역시  옹진군  영흥에너지파크   내국인                63,813   54,018      2,318
# 133  인천광역시  옹진군  영흥에너지파크   외국인                   619      619         20
# 134  인천광역시  옹진군  영흥에너지파크    합계                64,432   54,637      2,338
# 135  인천광역시  옹진군      자월면   내국인               283,582  147,060      1,723
# 136  인천광역시  옹진군      자월면    합계               283,582  147,060      1,723
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# ...

# %%
nav.reset_index(drop=False, inplace=True)

nav.columns = nav.iloc[0]

# %%
nav
# Out:
# 0      0    0    NaN  NaN      NaN  NaN      NaN      인원계  2019년 01월  \
# 0      0    0    NaN  NaN      NaN  NaN      NaN      인원계  2019년 01월
# 1      1    1  인천광역시   중구      무의도  내국인   58,787   58,787     12,589
# 2      2    2  인천광역시   중구      무의도   합계   58,787   58,787     12,589
# 3      3    3  인천광역시   중구  섬이야기박물관  내국인  101,945      NaN        NaN
# 4      4    4  인천광역시   중구  섬이야기박물관   합계  101,945      NaN        NaN
# ..   ...  ...    ...  ...      ...  ...      ...      ...        ...
# 132  132  132  인천광역시  옹진군  영흥에너지파크  내국인   63,813   54,018      2,318
# 133  133  133  인천광역시  옹진군  영흥에너지파크  외국인      619      619         20
# 134  134  134  인천광역시  옹진군  영흥에너지파크   합계   64,432   54,637      2,338
# 135  135  135  인천광역시  옹진군      자월면  내국인  283,582  147,060      1,723
# 136  136  136  인천광역시  옹진군      자월면   합계  283,582  147,060      1,723
#
# 0    2019년 02월  ...  2020년 08월  2020년 09월  2020년 10월  2020년 11월  2020년 12월  \
# ...

# %%
nav.columns = ['지역', '구분', '201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910',
       '201911', '201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010',
       '202011', '202012', '202101', '202102', '202103', '202104', '202105', '202106']

nav = nav.drop(0)
nav = nav.set_index(['지역','구분']) 

nav.columns = pd.to_datetime(nav.columns, format='%Y%m')

nav = nav.T

for (i, j) in nav.columns:
    nav.loc[:,(i,j)] = nav.loc[:,(i,j)].str.replace(',','').astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f9235cc75e58> in <module>
#       2
#       3 nav.columns = nav.iloc[0]
# ----> 4 nav.columns = ['지역', '구분', '201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910',
#       5        '201911', '201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010',
#       6        '202011', '202012', '202101', '202102', '202103', '202104', '202105', '202106']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5476         try:
#    5477             object.__getattribute__(self, name)
# -> 5478             return object.__setattr__(self, name, value)
#    5479         except AttributeError:
#    5480             pass
#
# ...
